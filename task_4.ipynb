# %% [markdown]
# # Task 4
# ## Team 15
# - Ahmed Hossam Sedky
# - Ahmed Mohamed Abdelfattah
# - Ehab Wahba Abdelrahman
# - Mo'men Maged Mohamed
# - Mohaned Alaa Ragab

# %% [markdown]
# **Import numpy and the required image processing functions**
#
# *Note: cv2 is only imported to open the image and get its dimensions*

# %%
# from libs import normalization, equalization, filters, noise, graphs, edge_detection, threshold
from libs import colorMap,segmentation, thresholding2
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/lenna.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
global_optimal = thresholding2.optimal(img)
local_optimal = thresholding2.LocalThresholding(img , 4 , thresholding2.optimal)
fig, axes = plt.subplots(1, 3, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(img , cmap="gray")
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(global_optimal , cmap="gray" )
ax[1].set_title('Global_Optimal')
ax[1].set_axis_off()


ax[2].imshow(local_optimal , cmap="gray"  )
ax[2].set_title('Local_Optimal')
ax[2].set_axis_off()
plt.tight_layout()
plt.show()

# %%
img = cv2.imread("images/lenna.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
global_otsu = thresholding2.otsu(img)
local_otsu = thresholding2.LocalThresholding(img , 4 , thresholding2.otsu)
fig, axes = plt.subplots(1, 3, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(img , cmap="gray")
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(global_otsu ,cmap="gray" )
ax[1].set_title('Global_Otsu')
ax[1].set_axis_off()


ax[2].imshow(local_otsu , cmap="gray" )
ax[2].set_title('Local_Otsu')
ax[2].set_axis_off()
plt.tight_layout()
plt.show()

# %%
img = cv2.imread("images/lenna.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
global_spectral = thresholding2.spectral(img)
local_spectral = thresholding2.LocalThresholding(img , 4 , thresholding2.spectral)
fig, axes = plt.subplots(1, 3, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(img , cmap="gray")
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(global_spectral , cmap="gray")
ax[1].set_title('Global_Spectral')
ax[1].set_axis_off()


ax[2].imshow(local_spectral , cmap="gray" )
ax[2].set_title('Local_Spectral')
ax[2].set_axis_off()
plt.tight_layout()
plt.show()
# Out:
# e:\computer-vision-basics\libs\thresholding2.py:175: RuntimeWarning: invalid value encountered in double_scalars
#   LowMean = sum(Low * PDF[LowT:HighT]) / CDFL

# %%
img = cv2.imread("images/test.png")
luv_img2 = cv2.cvtColor(img,cv2.COLOR_BGR2Luv)
b,g,r = cv2.split(img)       # get b,g,r
img = cv2.merge([r,g,b])     # switch it to rgb
cop_img = np.copy(img)
luv_img = colorMap.RGB2LUV(img)
fig, axes = plt.subplots(1, 3, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

print (luv_img[0,0])
ax[1].imshow(luv_img )
ax[1].set_title('Luv Image')
ax[1].set_axis_off()
print (luv_img2[0,0])

ax[2].imshow(luv_img2  )
ax[2].set_title('Luv Image cv')
ax[2].set_axis_off()
plt.tight_layout()
plt.show()
# Out:
# 110
# 95
# 140
# [110  95 140]
# [ 34  96 138]

# %%
img = cv2.imread("images/test.png")
cop_img = np.copy(img)
segmented_image ,labels = segmentation.apply_k_means (img)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(segmented_image )
ax[1].set_title('Luv Image')
ax[1].set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# 110
# 94
# 137
# len cluster: 0 = 35672
# cluster_mean 0: [220.93816   97.604706 147.08719 ]
# len cluster: 1 = 117952
# cluster_mean 1: [144.02509  76.85582 148.97073]
# len cluster: 2 = 50839
# cluster_mean 2: [178.9764  111.20561 205.15941]
# len cluster: 3 = 59419
# cluster_mean 3: [154.53976  66.89229 161.32686]
# len cluster: 4 = 72710
# cluster_mean 4: [196.4358   80.66038 135.74397]
# len cluster: 0 = 40505
# cluster_mean 0: [219.47522   96.874954 144.34131 ]
# len cluster: 1 = 91120
# cluster_mean 1: [131.65556  79.19187 152.4766 ]
# len cluster: 2 = 47877
# cluster_mean 2: [183.2016   112.319275 206.6655  ]
# len cluster: 3 = 77629
# cluster_mean 3: [160.61304  68.25519 156.77486]
# len cluster: 4 = 79461
# cluster_mean 4: [192.64911   78.329605 137.18625 ]
# len cluster: 0 = 44362
# cluster_mean 0: [218.41513  95.94559 142.52597]
# len cluster: 1 = 79639
# cluster_mean 1: [126.00558  78.29193 155.7002 ]
# len cluster: 2 = 48556
# ...

# %% [markdown]
# img = cv2.imread("images/test.png")
# cop_img = np.copy(img)
# segmented_image = segmentation.apply_region_growing (img)
# fig, axes = plt.subplots(1, 2, figsize=(15, 6))
# ax = axes.ravel()
#
# ax[0].imshow(cop_img)
# ax[0].set_title('Original Image')
# ax[0].set_axis_off()
#
# ax[1].imshow(segmented_image ,cmap = "gray")
# ax[1].set_title('segmented Image')
# ax[1].set_axis_off()
#
# plt.tight_layout()
# plt.show()

# %%
segmented_image = segmentation.apply_agglomerative_clustering(img,10,25)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(segmented_image ,cmap = "gray")
ax[1].set_title('segmented Image')
ax[1].set_axis_off()

plt.tight_layout()
plt.show()

# %%
image = cv2.imread("images/building.jpg")
b,g,r = cv2.split(image)       # get b,g,r
image = cv2.merge([r,g,b])     # switch it to rgb

cop_img = np.copy(image)
segmented_image = segmentation.apply_mean_shift(cop_img,60)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(image)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(segmented_image ,cmap = "gray")
ax[1].set_title('segmented Image')
ax[1].set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c52255339dbd> in <module>
#       1 image = cv2.imread("images/building.jpg")
# ----> 2 b,g,r = cv2.split(img)       # get b,g,r
#       3 image = cv2.merge([r,g,b])     # switch it to rgb
#       4
#       5 cop_img = np.copy(image)
#
# NameError: name 'img' is not defined
